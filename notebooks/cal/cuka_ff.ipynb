# %% [markdown]
# # Cu-K$\alpha$ line in EPIC-pn Full Frame mode

# %%
import os
import glob
import csv
import pickle

# %matplotlib inline
import matplotlib.pylab as plt

import pandas as pd
import numpy as np
#import altair as alt

from scipy.interpolate import interp1d
from scipy.interpolate import UnivariateSpline

# %%
# folder with the monitoring results
ddir = '/xdata/xcaldata/XMM/PN/CTI/dat_RLM'
wdir = os.path.join(os.path.expanduser('~'),'IVAN/Cu-line')
# build a list of all subfolders:
obsids = [f for f in os.listdir(ddir) if os.path.isdir(os.path.join(ddir, f))]
nobsid = len(obsids)

# %% [markdown]
# ## Merging all summary files in a table
#
# Each sub-folder of `ddir` contains a summary file with information about the observation. I combine all this info in a table and save it for easy access to the relevant `OBS_ID`.

# %%
output_file = f'{wdir}/ff_obsids_list.csv'
fout = open(output_file,'w')
print ("rev,obsid,expo,omode,filter,start,end,duration",file=fout)
for i,iobs in enumerate(obsids):
    #
    sumfile = glob.glob(f"{ddir}/{iobs}/{iobs}*smry.txt")
    # first extract useful info for the OBS_ID from the summary file
    if (len(sumfile) == 0):
        print (f"No summary file for OBS_ID {iobs}. Skipping it.")
        continue
    if (i % 100 == 0):
        print (f"Saving summary for {iobs} ({i+1}/{nobsid})")
    with open(sumfile[0], 'r') as sfile:
        csvreader = csv.reader(sfile)
        for row in csvreader:
            if row[0] in (None, ""):
                continue
            else:
                summary = row[0].replace("'","").split()
        #
    print (summary[0:8],file=fout)
#
fout.close()
# Out:
# Saving summary for 0021540401 (1/1336)
# Saving summary for 0112870701 (101/1336)
# Saving summary for 0112972001 (201/1336)
# Saving summary for 0411082701 (301/1336)
# Saving summary for 0125320801 (401/1336)
# Saving summary for 0406571001 (501/1336)
# Saving summary for 0505384501 (601/1336)
# Saving summary for 0552002701 (701/1336)
# Saving summary for 0651373201 (801/1336)
# Saving summary for 0671870601 (901/1336)
# Saving summary for 0690752101 (1001/1336)
# Saving summary for 9092100003 (1101/1336)
# Saving summary for 0134921001 (1201/1336)
# Saving summary for 0791780901 (1301/1336)
# No summary file for OBS_ID 0803080101. Skipping it.

# %%
# Out:
# 'PrimeFullWindow'

# %% [markdown]
# Now loop over all folders/obsids and get the Cu K$\alpha$ results. Skip files with zero length. Will check the boresight CCD 4 first

# %%
select_mode = "PrimeFullWindow"
list_file = f'{wdir}/ff_obsids_list.csv'
df = pd.read_csv(list_file)
df_sel = df.loc[df['omode'] == select_mode]
df_sel
# Out:
#        rev       obsid  expo            omode     filter                start  \
# 3      481    37982901  S001  PrimeFullWindow  CalClosed  2002-07-25T05:58:17
# 5      459    38140501  S005  PrimeFullWindow  CalClosed  2002-06-11T08:28:35
# 7      396     2970501  S005  PrimeFullWindow  CalClosed  2002-02-05T15:54:40
# 10     704    17740701  S003  PrimeFullWindow  CalClosed  2003-10-13T00:51:12
# 11     463    31740201  S005  PrimeFullWindow  CalClosed  2002-06-19T07:44:47
# 12     377     2740601  S005  PrimeFullWindow  CalClosed  2001-12-29T17:58:16
# 13     703    17740601  S003  PrimeFullWindow  CalClosed  2003-10-11T00:59:42
# 16     380    42341501  S005  PrimeFullWindow  CalClosed  2002-01-04T17:46:53
# 17     504    30540201  U002  PrimeFullWindow  CalClosed  2002-09-09T10:19:08
# 18     696    65820601  S015  PrimeFullWindow  CalClosed  2003-09-27T01:58:14
# 20     383    52140401  S005  PrimeFullWindow  CalClosed  2002-01-10T17:10:22
# 22     368    56022101  S005  PrimeFullWindow  CalClosed  2001-12-11T18:50:41
# 23     204    56030101  U002  PrimeFullWindow  CalClosed  2001-01-19T13:17:41
# 24     694    65820201  S003  PrimeFullWindow  CalClosed  2003-09-23T02:14:10
# 25     378    47940201  S005  PrimeFullWindow  CalClosed  2001-12-31T17:52:52
# 27     395    91770201  S005  PrimeFullWindow  CalClosed  2002-02-03T16:05:32
# 28     419    40140501  S005  PrimeFullWindow  CalClosed  2002-03-23T13:08:28
# 30     445    41740801  S005  PrimeFullWindow  CalClosed  2002-05-14T10:16:21
# 32     370    83000701  S005  PrimeFullWindow  CalClosed  2001-12-15T18:39:51
# 35     227    22940301  S002  PrimeFullWindow  CalClosed  2001-03-05T10:58:31
# 37     373    93060301  S005  PrimeFullWindow  CalClosed  2001-12-21T18:24:33
# 39     207    67190301  S003  PrimeFullWindow  CalClosed  2001-01-24T13:19:51
# 44     403   109464101  S005  PrimeFullWindow  CalClosed  2002-02-19T15:30:50
# 45     226    21750801  S006  PrimeFullWindow  CalClosed  2001-03-03T10:56:32
# 47     379   109471101  S005  PrimeFullWindow  CalClosed  2002-01-02T18:03:46
# 50     600    46540201  S003  PrimeFullWindow  CalClosed  2003-03-19T14:37:52
# 52    1316   400920301  S005  PrimeFullWindow  CalClosed  2007-02-16T03:57:33
# 53     325   109260301  S005  PrimeFullWindow  CalClosed  2001-09-17T00:58:50
# 56     417    25541801  S005  PrimeFullWindow  CalClosed  2002-03-19T13:25:11
# 58     394   109520701  S005  PrimeFullWindow  CalClosed  2002-02-01T16:10:12
# ...    ...         ...   ...              ...        ...                  ...
# 1292  2196   677380201  S003  PrimeFullWindow  CalClosed  2011-12-05T16:32:59
# 1293   125   110010101  U002  PrimeFullWindow  CalClosed  2000-08-14T11:59:46
# 1294  2243  9224300005  U002  PrimeFullWindow     Closed  2012-03-09T11:53:47
# 1295  3022  9302200002  U002  PrimeFullWindow  CalClosed  2016-06-09T09:30:41
# 1296  3149   747790801  S003  PrimeFullWindow  CalClosed  2017-02-18T15:58:53
# 1297  3163   784520101  U002  PrimeFullWindow  CalClosed  2017-03-17T07:04:42
# 1298  3189   791780701  S001  PrimeFullWindow  CalClosed  2017-05-07T23:13:57
# 1299  3189   791780801  S001  PrimeFullWindow  CalClosed  2017-05-08T04:25:38
# 1300  3189   791780901  S001  PrimeFullWindow  CalClosed  2017-05-08T08:13:58
# 1301  3187   791781001  S001  PrimeFullWindow  CalClosed  2017-05-03T23:30:16
# 1303  3195   801271101  U014  PrimeFullWindow  CalClosed  2017-05-21T12:35:03
# 1305  1978  9197800004  U002  PrimeFullWindow  CalClosed  2010-09-28T07:36:53
# 1306  2811  9281100003  U002  PrimeFullWindow  CalClosed  2015-04-16T09:25:10
# 1307  2812  9281200004  U002  PrimeFullWindow  CalClosed  2015-04-18T08:28:52
# 1309  3241   795781001  S003  PrimeFullWindow  CalClosed  2017-08-20T21:47:21
# 1310  3253   800760901  U002  PrimeFullWindow  CalClosed  2017-09-12T19:48:48
# 1311  3259   803990701  S026  PrimeFullWindow     Closed  2017-09-24T22:38:43
# 1314  3284   810242001  S008  PrimeFullWindow  CalClosed  2017-11-14T07:23:32
# 1315  3287   791781401  S600  PrimeFullWindow  CalClosed  2017-11-19T10:07:51
# 1316  3289   802710601  S003  PrimeFullWindow  CalClosed  2017-11-23T09:51:12
# 1317  3324   810400801  S003  PrimeFullWindow  CalClosed  2018-02-02T15:31:14
# 1318  3373   791782001  S600  PrimeFullWindow  CalClosed  2018-05-09T22:17:01
# 1321  3419   821040601  S003  PrimeFullWindow  CalClosed  2018-08-09T16:12:27
# 1323  3425   830790101  S001  PrimeFullWindow  CalClosed  2018-08-22T18:46:18
# 1324  3432   831410101  S003  PrimeFullWindow  CalClosed  2018-09-04T15:20:00
# 1325  3442   820310401  S003  PrimeFullWindow  CalClosed  2018-09-24T13:03:09
# 1326  3441   822340101  S003  PrimeFullWindow  CalClosed  2018-09-22T14:07:35
# 1331  3471   810860201  S600  PrimeFullWindow  CalClosed  2018-11-21T13:18:03
# 1332  3461   820912601  S003  PrimeFullWindow  CalClosed  2018-11-01T10:28:06
# 1334  3492  9349200003  U002  PrimeFullWindow  CalClosed  2019-01-03T18:50:13
#
#                       end  duration
# 3     2002-07-25T06:02:24       0.0
# 5     2002-06-11T08:32:44     248.3
# 7     2002-02-05T16:08:47     848.0
# 10    2003-10-13T01:19:39    1707.9
# 11    2002-06-19T07:57:15     747.1
# 12    2001-12-29T18:19:55    1299.6
# 13    2003-10-11T01:28:09    1708.2
# 16    2002-01-04T18:00:11     799.5
# 17    2002-09-09T10:43:49    1480.7
# 18    2003-09-27T02:16:54    1121.0
# 20    2002-01-10T17:32:01    1299.9
# 22    2001-12-11T19:09:10    1109.3
# 23    2001-01-19T13:32:35     894.9
# 24    2003-09-23T02:41:45    1655.8
# 25    2001-12-31T18:16:12    1399.1
# 27    2002-02-03T16:15:20     588.2
# 28    2002-03-23T13:37:36    1747.7
# 30    2002-05-14T10:52:57    2196.8
# 32    2001-12-15T18:58:20    1110.2
# 35    2001-03-05T11:41:28    2385.1
# 37    2001-12-21T18:46:22    1309.9
# 39    2001-01-24T13:49:07    1749.8
# 44    2002-02-19T15:33:38     168.1
# 45    2001-03-03T11:47:25    3050.6
# 47    2002-01-02T18:08:43     297.0
# 50    2003-03-19T16:12:18    5667.4
# 52    2007-02-16T05:38:10    6036.3
# 53    2001-09-17T01:31:00    1930.3
# 56    2002-03-19T14:38:43    4412.6
# 58    2002-02-01T16:24:19     847.7
# ...                   ...       ...
# 1292  2011-12-07T06:13:48  135594.5
# 1293  2000-08-14T16:48:46   17101.7
# 1294  2012-03-09T13:19:36    2269.2
# 1295  2016-06-09T10:32:35    3714.0
# 1296  2017-02-18T19:19:33   12005.7
# 1297  2017-03-17T15:09:25   29042.6
# 1298  2017-05-08T03:16:19   14541.1
# 1299  2017-05-08T07:04:39    9540.2
# 1300  2017-05-08T10:52:59    9539.0
# 1301  2017-05-04T03:32:37   14541.0
# 1303  2017-05-21T14:08:13    5586.2
# 1305  2010-09-28T11:45:20   14764.5
# 1306  2015-04-16T17:30:29   28876.5
# 1307  2015-04-18T20:15:16   41967.7
# 1309  2017-08-21T06:39:41   31937.2
# 1310  2017-09-14T04:36:52  118050.7
# 1311  2017-09-26T03:25:23  103559.5
# 1314  2017-11-14T09:29:34    7561.8
# 1315  2017-11-20T00:53:33   53129.3
# 1316  2017-11-23T09:54:26     193.4
# 1317  2018-02-02T18:51:54   12040.9
# 1318  2018-05-10T02:06:23   13762.2
# 1321  2018-08-09T20:55:09   16955.1
# 1323  2018-08-23T04:47:19   36056.1
# 1324  2018-09-05T03:19:22   43125.5
# 1325  2018-09-24T14:06:15    3785.5
# 1326  2018-09-24T03:53:37  135861.3
# 1331  2018-11-22T02:44:05   48307.3
# 1332  2018-11-01T11:39:08    4261.6
# 1334  2019-01-03T21:18:31    8896.0
#
# [1103 rows x 8 columns]

# %%
result = {}
for j in np.arange(1,13):
    result[j] = {'cuka': [], 'cuka_err1': [], 'cuka_err2': [], 'revol': [], 
                        'chi2': [], 'dof': [], 'chi2r': []}
    #
for iobs,irev in zip(df_sel.obsid,df_sel.rev):
    for iccd in np.arange(1,13):
        xfile = glob.glob(f"{ddir}/{iobs:010}/{iobs:010}*lmonCCD{iccd:02}_Cu-Ka.txt")
        if (len(xfile) > 0):
            with open(xfile[0], 'r') as datfile:
                csvreader = csv.reader(datfile)
                for row in csvreader:
                    if row[0] in (None, ""):
                        continue
                    else:
                        results = row[0].split()
            #
            result[iccd]['cuka'].append(float(results[4]))
            result[iccd]['cuka_err1'].append(float(results[5]))
            result[iccd]['cuka_err2'].append(float(results[6]))
            result[iccd]['chi2'].append(float(results[24]))
            result[iccd]['dof'].append(int(results[25]))
            if (int(results[25]) > 0):
                result[iccd]['chi2r'].append(float(results[24])/int(results[25]))
            else:
                result[iccd]['chi2r'].append(-9.0)
            result[iccd]['revol'].append(int(irev))
        #break
#
for j in np.arange(1,13):
    print (f"Found {len(result[j]['cuka'])} OBS_IDs with Cu Ka line results for mode {select_mode} for CCDNR == {j}")
#
# Out:
# Found 543 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 1
# Found 653 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 2
# Found 653 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 3
# Found 538 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 4
# Found 641 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 5
# Found 651 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 6
# Found 514 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 7
# Found 627 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 8
# Found 636 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 9
# Found 512 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 10
# Found 631 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 11
# Found 641 OBS_IDs with Cu Ka line results for mode PrimeFullWindow for CCDNR == 12

# %%
resfile = f'{wdir}/ff_cuka_fit_results.pickle'
with open(resfile, 'wb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    pickle.dump(result, f, pickle.HIGHEST_PROTOCOL)

# %%
resfile = f'{wdir}/ff_cuka_fit_results.pickle'
with open(resfile, 'rb') as f:
    # The protocol version used is detected automatically, so we do not
    # have to specify it.
    result = pickle.load(f)

# %%
fig, axs = plt.subplots(2,6,sharex=True,sharey=True,figsize=(15,10))
#
chi2r_lim = 1.3
#
mapping = {1: [0,2], 2: [0,1], 3: [0,0], 4: [0,3], 5: [0,4], 6: [0,5],
          7: [1,3], 8: [1,4], 9: [1,5], 10: [1,2], 11: [1,1], 12: [1,0]}
#
runrev = np.arange(0.0,3500.0,200.0)
#
for j in np.arange(12):
    ccd = j + 1
    #
    #
    # filter only those with good fit, i.e. chi2r above chi2r_lim
    #
    #ix = np.where(np.asarray(result[ccd]['chi2r']) <= chi2r_lim)[0]
    # 
    uncert = (np.asarray(result[ccd]['cuka_err2']) - np.asarray(result[ccd]['cuka_err1']))*5
    ix = np.where((uncert <= 50.0) & (uncert > 0.0))[0]
    print (f"Selected {len(ix)}/{len(result[ccd]['chi2r'])} good fit results for CCD {ccd}")
    #
    xrev = np.asarray(result[ccd]['revol'])[ix]
    xcu = np.asarray(result[ccd]['cuka'])[ix]*5.0 # in eV
    xcu_e1 = np.asarray(result[ccd]['cuka_err1'])[ix]*5.0 # in eV
    xcu_e2 = np.asarray(result[ccd]['cuka_err2'])[ix]*5.0 # in eV
    diff = xcu - 8040.0 # in eV
    diff_err1 = xcu - xcu_e1
    diff_err2 = xcu_e2 - xcu
    diff_err = (diff_err1 + diff_err2)/2.0
    #
    # for the spline we need unique x and strictly increasing
    #qrev, inx = np.unique(xrev, return_index=True)
    #qdif = diff[inx]
    #qdiferr = diff_err[inx]
    #isort = qrev.argsort()
    #
    # smooth curve with univariate weighted spline
    #wxx = 1.0/np.power(qdiferr,2)
    #s = UnivariateSpline(qrev[isort], qdif[isort], w=wxx[isort], k=4,s=2)
    #z = np.polyfit(qrev[isort], qdif[isort], 1)
    #p = np.poly1d(z)
    #qresult = p(runrev)
    #qresult = s(runrev)
    #
    # get the median
    #
    med = np.quantile(diff,0.5)
    mplus = np.quantile(diff,0.84)
    mminus = np.quantile(diff,0.16)
    axs[mapping[ccd][0],mapping[ccd][1]].errorbar(xrev,diff,yerr=(diff_err1,diff_err2),fmt='o',
                                                  ms=4,ecolor='grey',label=f'CCD #{ccd:02}',alpha=0.2)
    #axs[mapping[ccd][0],mapping[ccd][1]].plot(runrev,qresult,color='red')
    axs[mapping[ccd][0],mapping[ccd][1]].axhline(med,color='red',lw=2)
    axs[mapping[ccd][0],mapping[ccd][1]].axhline(mplus,color='red',ls='dashed',lw=2)
    axs[mapping[ccd][0],mapping[ccd][1]].axhline(mminus,color='red',ls='dashed',lw=2)
    #axs[kj,k].plot(xrev,diff,'ok',label='')
    axs[mapping[ccd][0],mapping[ccd][1]].axhline(0.0,color='black',ls='dashed',lw=2)
    axs[mapping[ccd][0],mapping[ccd][1]].text(1000,130,f"median={med:.1f}")
    axs[mapping[ccd][0],mapping[ccd][1]].text(1200,110,f"({mminus:.1f},{mplus:.1f},68%)")
    #
    axs[mapping[ccd][0],mapping[ccd][1]].set_xlim((0,3600))
    axs[mapping[ccd][0],mapping[ccd][1]].set_ylim((-200.0,200.0))
    axs[mapping[ccd][0],mapping[ccd][1]].grid(True)
    axs[mapping[ccd][0],mapping[ccd][1]].legend(loc=1)
    if (ccd == 4):
        axs[mapping[ccd][0],mapping[ccd][1]].set_title(fr"Cu K$\alpha$ fit for EPIC-PN {select_mode}")
    if (ccd == 3 or ccd == 12):
        axs[mapping[ccd][0],mapping[ccd][1]].set_ylabel(r"$\Delta$ Eobs - Elab (eV)")
    if (ccd == 10):
        axs[mapping[ccd][0],mapping[ccd][1]].set_xlabel("Revolution")
#
plt.subplots_adjust(wspace=0, hspace=0)
plt.savefig(f"{wdir}/ff_cuka_monitoring_results.png",dpi=100)
#plt.savefig(f"{wdir}/../cuka_results_all_cti49_test51_plot.png",dpi=100)
#plt.savefig(f"{wdir}/../cuka_results_allccd_myproc_plot.png",dpi=100)
plt.show();
plt.close();
# Out:
# Selected 435/543 good fit results for CCD 1
# Selected 556/653 good fit results for CCD 2
# Selected 557/653 good fit results for CCD 3
# Selected 426/538 good fit results for CCD 4
# Selected 531/641 good fit results for CCD 5
# Selected 555/651 good fit results for CCD 6
# Selected 399/514 good fit results for CCD 7
# Selected 526/627 good fit results for CCD 8
# Selected 525/636 good fit results for CCD 9
# Selected 403/512 good fit results for CCD 10
# Selected 509/631 good fit results for CCD 11
# Selected 537/641 good fit results for CCD 12

# %%
#d = {'rev': xrev, 'cuka': , 'cuka_err1': [float(x) for x in cuka_err1], 'cuka_err2': [float(x) for x in cuka_err2]}
#d = {'rev': xrev, 'cuka': , 'cuka_err1': [float(x) for x in cuka_err1], 'cuka_err2': [float(x) for x in cuka_err2]}
#df = pd.DataFrame(data=d)

# %%
cuka0 = 8040 # lab energy in ADUs
diff = df.cuka*5.0 - cuka0
cukaerr1 = df.cuka - df.cuka_err1
cukaerr2 = df.cuka_err2 - df.cuka

# the base chart
#base = alt.Chart(df,title=r"Cu K$\alpha$ monitoring results",width=800,height=500).transform_calculate(
#    ymin="datum.cuka_err1",
#    ymax="datum.cuka_err2"
#)

#points = base.mark_circle(size=60).encode(
#    alt.X('rev',scale=alt.Scale(domain=(0,3500))),
#    alt.Y('cuka',scale=alt.Scale(domain=(1500,1800))),
#    tooltip=['rev', 'cuka','cuka_err1', 'cuka_err2']
#)

#points = alt.Chart(df,title=r"Cu K$\alpha$ monitoring results",width=800,height=500).mark_circle(size=60).encode(
#    alt.X('rev',scale=alt.Scale(domain=(0,3500))),
#    alt.Y('cuka',scale=alt.Scale(domain=(1500,1800))),
#    tooltip=['rev', 'cuka','cuka_err1', 'cuka_err2']
#).interactive()

# generate the error bars
#errorbars = base.mark_errorbar().encode(
#    x="rev",
#    y="ymin:Q",
#    y2="ymax:Q"
#)

#points
fig, ax = plt.subplots(figsize=(15,10))
ax.errorbar(df.rev,diff,yerr=(cukaerr1,cukaerr2),fmt='o')
ax.axhline(0.0,linestyle='dashed',color='black')
ax.set_ylim([-200,200])
ax.grid()
ax.set_xlabel('revolution')
ax.set_ylabel(r'Cu K$\alpha$ obs - lab (eV)');
ax.set_title(fr"Cu K$\alpha$ results for EPIC-pn {select_mode}, CCDNR = {ccdnr}")
plt.show();

# %%
diff.__class__
# Out:
# pandas.core.series.Series

# %%
dir(base)
# Out:
# ['autosize',
#  'background',
#  'config',
#  'data',
#  'datasets',
#  'description',
#  'encoding',
#  'height',
#  'mark',
#  'name',
#  'padding',
#  'projection',
#  'selection',
#  'title',
#  'transform',
#  'width']
